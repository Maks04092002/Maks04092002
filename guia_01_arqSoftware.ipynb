# %% [markdown]
# <a href="https://colab.research.google.com/github/Maks04092002/Maks04092002/blob/main/guia_01_arqSoftware.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyecto Integrador - Arquitectura de Software
#
# **Estudiante:** [Maks Brayan Tanta Chala ][cite: 1]
# **Docente:** Ing. Lizbeth Jaico Quispe[cite: 1]
# **Curso:** Arquitectura de Software (IS-488)[cite: 1]
#
# ## Descripción del curso
# [La arquitectura de software es el plano general o diseño de más alto nivel de un sistema informático que define cómo se organizan, interactúan y comunican sus componentes][cite: 1]
#
# ## Expectativas del estudiante
# [Aplicación práctica: Adquirir habilidades teóricas que pueda aplicar directamente en proyectos reales y en el mundo profesional.Actualización tecnológica: Conocer las herramientas, metodologías y tendencias más vigentes del sector.Resolución de problemas: Desarrollar un pensamiento crítico para resolver desafíos complejos de la materia.][cite: 1]
#
# ## Capturas de pantalla
# * Captura del Paso 01: Verificación de versiones de herramientas
# ![Imagen1.png](data:image/png;base64,...)[cite: 1].
# * Captura del Paso 02: Creación de la estructura de carpetas
# ![Captura de pantalla 2026-09-18 153500.png](data:image/png;base64,...)[cite: 1].
